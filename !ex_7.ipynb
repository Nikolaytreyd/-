# %%
from pandas import DataFrame as df

oscar_data = [
    ['Форма воды', 2017, 6.914, 123, ['фантастика', 'драма'], 19.4, 195.243464],
    ['Лунный свет', 2016, 6.151, 110, ['драма'], 1.5, 65.046687],
    ['В центре внимания', 2015, 7.489, 129, ['драма', 'криминал', 'история'], 20.0, 88.346473],
    ['Бёрдмэн', 2014, 7.604, 119, ['драма', 'комедия'], 18.0, 103.215094],
    ['12 лет рабства', 2013, 7.71, 133, ['драма', 'биография', 'история'], 20.0, 178.371993],
    ['Операция "Арго"', 2012, 7.517, 120, ['триллер', 'драма', 'биография'], 44.5, 232.324128],
    ['Артист', 2011, 7.942, 96, ['драма', 'мелодрама', 'комедия'], 15.0, 133.432856],
    ['Король говорит!', 2010, 7.977, 118, ['драма', 'биография', 'история'], 15.0, 414.211549],
    ['Повелитель бури', 2008, 7.298, 126, ['триллер', 'драма', 'военный', 'история'], 15.0, 49.230772],
    ['Миллионер из трущоб', 2008, 7.724, 120, ['драма', 'мелодрама'], 15.0, 377.910544],
    ['Старикам тут не место', 2007, 7.726, 122, ['триллер', 'драма', 'криминал'], 25.0, 171.627166],
    ['Отступники', 2006, 8.456, 151, ['триллер', 'драма', 'криминал'], 90.0, 289.847354],
    ['Столкновение', 2004, 7.896, 108, ['триллер', 'драма', 'криминал'], 6.5, 98.410061],
    ['Малышка на миллион', 2004, 8.075, 132, ['драма', 'спорт'], 30.0, 216.763646],
    ['Властелин колец: Возвращение Короля', 2003, 8.617, 201, ['фэнтези', 'драма', 'приключения'], 94.0, 1119.110941],
    ['Чикаго', 2002, 7.669, 113, ['мюзикл', 'комедия', 'криминал'], 45.0, 306.776732],
    ['Игры разума', 2001, 8.557, 135, ['драма', 'биография', 'мелодрама'], 58.0, 313.542341],
    ['Гладиатор', 2000, 8.585, 155, ['боевик', 'драма', 'приключения'], 103.0, 457.640427],
    ['Красота по-американски', 1999, 7.965, 122, ['драма'], 15.0, 356.296601],
    ['Влюбленный Шекспир', 1998, 7.452, 123, ['драма', 'мелодрама', 'комедия', 'история'], 25.0, 289.317794],
    ['Титаник', 1997, 8.369, 194, ['драма', 'мелодрама'], 200.0, 2185.372302],
    ['Английский пациент', 1996, 7.849, 155, ['драма', 'мелодрама', 'военный'], 27.0, 231.976425],
    ['Храброе сердце', 1995, 8.283, 178, ['драма', 'военный', 'биография', 'история'], 72.0, 210.409945],
    ['Форрест Гамп', 1994, 8.915, 142, ['драма', 'мелодрама'], 55.0, 677.386686],
    ['Список Шиндлера', 1993, 8.819, 195, ['драма', 'биография', 'история'], 22.0, 321.265768],
    ['Непрощенный', 1992, 7.858, 131, ['драма', 'вестерн'], 14.4, 159.157447],
    ['Молчание ягнят', 1990, 8.335, 114, ['триллер', 'криминал', 'детектив', 'драма', 'ужасы'], 19.0, 272.742922],
    ['Танцующий с волками', 1990, 8.112, 181, ['драма', 'приключения', 'вестерн'], 22.0, 424.208848],
    ['Шофёр мисс Дэйзи', 1989, 7.645, 99, ['драма'], 7.5, 145.793296],
# 27                [драма, приключения, вестерн]       22.0   424.208848
# 28                                      [драма]        7.5   145.793296
# 29                                      [драма]       25.0   354.825435

# %%
import requests

def get_exchange_rate():
    url = 'https://api.exchangerate-api.com/v4/latest/USD'
    response = requests.get(url)
    data = response.json()
    rate = data['rates']['RUB']
    return rate

# Пример использования функции
exchange_rate = get_exchange_rate()

# %%
data['Длительность в часах'] = data['Длина, мин'] / 60
data['Стоимость минуты'] = data['Бюджет, $'] * exchange_rate /  data['Длина, мин']
data['Долго_Коротко'] = data['Длительность в часах'] > 2
data['Долго_Коротко'] = data['Долго_Коротко'].replace([True, False], ['Долго', 'Коротко'])
data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_74112\3579614266.py:7: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. ser.count(level=1) should use ser.groupby(level=1).count().
#   data[data['Жанр'].count('драма') != 0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 7
#       4 data['Долго_Коротко'] = data['Долго_Коротко'].replace([True, False], ['Долго', 'Коротко'])
#       5 data
# ----> 7 data[data['Жанр'].count('драма') != 0]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:2129, in Series.count(self, level)
#    2121     warnings.warn(
#    2122         "Using the level keyword in DataFrame and Series aggregations is "
#    2123         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#    2126         stacklevel=find_stack_level(),
#    2127     )
#    2128     if not isinstance(self.index, MultiIndex):
# -> 2129         raise ValueError("Series.count level is only valid with a MultiIndex")
#    2131 index = self.index
#    2132 assert isinstance(index, MultiIndex)  # for mypy
#
# ValueError: Series.count level is only valid with a MultiIndex

# %%
def name_creat(name:str):
    mass = []
    for id in list(data['Жанр']):
        if name in id:
            mass.append(True)
        else:
            mass.append(False)
    data[name] = mass
    return data

name_creat('вестерн')
# Out:
#                                Название   Год  Рейтинг  Длина, мин  \
# 0                            Форма воды  2017    6.914         123
# 1                           Лунный свет  2016    6.151         110
# 2                     В центре внимания  2015    7.489         129
# 3                               Бёрдмэн  2014    7.604         119
# 4                        12 лет рабства  2013    7.710         133
# 5                       Операция "Арго"  2012    7.517         120
# 6                                Артист  2011    7.942          96
# 7                       Король говорит!  2010    7.977         118
# 8                       Повелитель бури  2008    7.298         126
# 9                   Миллионер из трущоб  2008    7.724         120
# 10                Старикам тут не место  2007    7.726         122
# 11                           Отступники  2006    8.456         151
# 12                         Столкновение  2004    7.896         108
# 13                   Малышка на миллион  2004    8.075         132
# 14  Властелин колец: Возвращение Короля  2003    8.617         201
# 15                               Чикаго  2002    7.669         113
# 16                          Игры разума  2001    8.557         135
# 17                            Гладиатор  2000    8.585         155
# 18               Красота по-американски  1999    7.965         122
# 19                   Влюбленный Шекспир  1998    7.452         123
# 20                              Титаник  1997    8.369         194
# 21                   Английский пациент  1996    7.849         155
# 22                       Храброе сердце  1995    8.283         178
# 23                         Форрест Гамп  1994    8.915         142
# 24                      Список Шиндлера  1993    8.819         195
# 25                          Непрощенный  1992    7.858         131
# 26                       Молчание ягнят  1990    8.335         114
# 27                  Танцующий с волками  1990    8.112         181
# 28                     Шофёр мисс Дэйзи  1989    7.645          99
# 29                        Человек дождя  1988    8.250         133
#
#                                            Жанр  Бюджет, $     Сборы, $  \
# 0                           [фантастика, драма]       19.4   195.243464
# 1                                       [драма]        1.5    65.046687
# 2                    [драма, криминал, история]       20.0    88.346473
# 3                              [драма, комедия]       18.0   103.215094
# 4                   [драма, биография, история]       20.0   178.371993
# 5                   [триллер, драма, биография]       44.5   232.324128
# 6                   [драма, мелодрама, комедия]       15.0   133.432856
# 7                   [драма, биография, история]       15.0   414.211549
# 8            [триллер, драма, военный, история]       15.0    49.230772
# 9                            [драма, мелодрама]       15.0   377.910544
# 10                   [триллер, драма, криминал]       25.0   171.627166
# 11                   [триллер, драма, криминал]       90.0   289.847354
# 12                   [триллер, драма, криминал]        6.5    98.410061
# 13                               [драма, спорт]       30.0   216.763646
# 14                [фэнтези, драма, приключения]       94.0  1119.110941
# 15                  [мюзикл, комедия, криминал]       45.0   306.776732
# 16                [драма, биография, мелодрама]       58.0   313.542341
# 17                 [боевик, драма, приключения]      103.0   457.640427
# 18                                      [драма]       15.0   356.296601
# 19         [драма, мелодрама, комедия, история]       25.0   289.317794
# 20                           [драма, мелодрама]      200.0  2185.372302
# 21                  [драма, мелодрама, военный]       27.0   231.976425
# 22         [драма, военный, биография, история]       72.0   210.409945
# 23                           [драма, мелодрама]       55.0   677.386686
# 24                  [драма, биография, история]       22.0   321.265768
# 25                             [драма, вестерн]       14.4   159.157447
# 26  [триллер, криминал, детектив, драма, ужасы]       19.0   272.742922
# 27                [драма, приключения, вестерн]       22.0   424.208848
# 28                                      [драма]        7.5   145.793296
# 29                                      [драма]       25.0   354.825435
#
#     Длительность в часах  Стоимость минуты Долго_Коротко  вестерн
# 0               2.050000         14.587854         Долго    False
# 1               1.833333          1.261227       Коротко    False
# 2               2.150000         14.339535         Долго    False
# 3               1.983333         13.990084       Коротко    False
# 4               2.216667         13.908271         Долго    False
# 5               2.000000         34.298375       Коротко    False
# 6               1.600000         14.451562       Коротко    False
# 7               1.966667         11.757203       Коротко    False
# 8               2.100000         11.010714         Долго    False
# 9               2.000000         11.561250       Коротко    False
# 10              2.033333         18.952869         Долго    False
# 11              2.516667         55.126490         Долго    False
# 12              1.800000          5.566528       Коротко    False
# 13              2.200000         21.020455         Долго    False
# 14              3.350000         43.254030         Долго    False
# 15              1.883333         36.832301       Коротко    False
# 16              2.250000         39.736444         Долго    False
# 17              2.583333         61.461097         Долго    False
# 18              2.033333         11.371721         Долго    False
# 19              2.050000         18.798780         Долго    False
# 20              3.233333         95.350515         Долго    False
# 21              2.583333         16.111161         Долго    False
# 22              2.966667         37.411685         Долго    False
# 23              2.366667         35.823592         Долго    False
# 24              3.250000         10.434769         Долго    False
# 25              2.183333         10.166840         Долго     True
# 26              1.900000         15.415000       Коротко    False
# 27              3.016667         11.241878         Долго     True
# 28              1.650000          7.006818       Коротко    False
# 29              2.216667         17.385338         Долго    False

# %%
from matplotlib import pyplot as plt

main = sum(list(data['Жанр']), [])
unic = list(set(main))
volume = [main.count(obj) for obj in unic]
label = [i for i in range(len(unic))]

plt.hist(volume, bins=len(unic))
#plt.xticks(label, unic)
plt.show()

# %%
len(unic), len(label)
# Out:
# (17, 17)
